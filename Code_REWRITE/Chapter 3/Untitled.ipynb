# %%
import os
import numpy as np
import pandas as pd
home_folder = os.path.expanduser("~")
data_folder = os.path.join("D:\git\Code_REWRITE\Chapter 3")
print(data_folder)
data_filename = os.path.join(data_folder, "feeds.dat")
# Out:
# D:\git\Code_REWRITE\Chapter 3

# %%
results = pd.read_csv(data_filename, parse_dates=True, skiprows=[0,])
# Fix the name of the columns
results.columns = ["ID", "content","device", "isdeleted", "room", "stat", "time", "top","user"]
#results = results.DataFrame(columns=['A', 'B', 'C', 'D'])
results.loc[-5:]
# Out:
#                                         ID  \
# 0       ObjectId(550c0928fbe78e19d5f85e19)
# 1       ObjectId(550c15d9fbe78e19d5f85ed4)
# 2       ObjectId(550c09f4fbe78e19d5f85e2c)
# 3       ObjectId(550c17c4fbe78e19d5f85f07)
# 4       ObjectId(550c1c6efbe78e19d5f85fd1)
# 5       ObjectId(550c0bc3fbe78e19d5f85e5b)
# 6       ObjectId(550c1c79fbe78e19d5f85fd3)
# 7       ObjectId(550c1054fbe78e19d5f85e89)
# 8       ObjectId(550c280afbe78e19d5f860ae)
# 9       ObjectId(550c1946fbe78e19d5f85f49)
# 10      ObjectId(550c2874fbe78e19d5f860ca)
# 11      ObjectId(550c1b2efbe78e19d5f85f9d)
# 12      ObjectId(550c2bcbfbe78e19d5f86156)
# 13      ObjectId(550c209bfbe78e19d5f86010)
# 14      ObjectId(550c2c75fbe78e19d5f86171)
# 15      ObjectId(550c3223fbe78e19d5f8621e)
# 16      ObjectId(550c2717fbe78e19d5f86097)
# 17      ObjectId(550c3658fbe78e19d5f862d6)
# 18      ObjectId(550c2a0ffbe78e19d5f8611b)
# 19      ObjectId(550c3965fbe78e19d5f863ac)
# 20      ObjectId(550c2b1cfbe78e19d5f8614c)
# ...

# %%
results.iloc[400000:400050]["stat"]
# Out:
# 400000                        NaN
# 400001     {"comment":1,"like":3}
# 400002     {"comment":3,"like":1}
# 400003                 {"like":1}
# 400004                        NaN
# 400005                 {"like":1}
# 400006              {"comment":5}
# 400007                 {"like":1}
# 400008                 {"like":3}
# 400009              {"comment":2}
# 400010     {"comment":6,"like":1}
# 400011                        NaN
# 400012                 {"like":1}
# 400013     {"comment":3,"like":1}
# 400014                        NaN
# 400015                        NaN
# 400016     {"comment":3,"like":2}
# 400017             {"comment":15}
# 400018                        NaN
# 400019     {"comment":5,"like":1}
# 400020     {"comment":4,"like":1}
# 400021              {"comment":4}
# 400022     {"comment":1,"like":1}
# 400023     {"comment":8,"like":1}
# 400024              {"comment":1}
# 400025    {"comment":27,"like":2}
# 400026                        NaN
# ...

# %%
print(len(results))
# Out:
# 473895

# %%
import time
from datetime import date, datetime
results.iloc[1]["time"][26:39]
print(int(results.iloc[400000]["time"][26:39]))
result_time = int(results.iloc[400000]["time"][26:36])
print(type(result_time))
#x = time.localtime(result_time)
#print(x)
D1 = datetime.fromtimestamp(result_time)
#D2 = date.fromtimestamp(result_time)
#date('Y-m-d',result_time)
print(D1)
#time.strftime('%Y-%m-%d %H:%M:%S',x)
# Out:
# 1435661220920
# <class 'int'>
# 2015-06-30 18:47:00

# %%
func
